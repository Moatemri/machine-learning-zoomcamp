# %%
import pandas as pd

# %%
pd.read_csv('wget https://raw.githubusercontent.com/DataTalksClub/machine-learning-zoomcamp/main/cohorts/2026/data/car_fuel_efficiency_2026.csv
')
# Out:
#   Cell In[3], line 1
#     pd.read_csv('wget https://raw.githubusercontent.com/DataTalksClub/machine-learning-zoomcamp/main/cohorts/2026/data/car_fuel_efficiency_2026.csv
#                 ^
# SyntaxError: unterminated string literal (detected at line 1)
